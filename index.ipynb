# %% [markdown]
# # Project - Data Cleaning
#
# ## Introduction
# In this lab, we'll make use of everything we've learned about pandas, data cleaning, and exploratory data analysis. In order to complete this lab, you'll have to import, clean, combine, reshape, and visualize data to answer questions provided, as well as your own questions!
#
# ## Objectives
# You will be able to:
# - Use different types of joins to merge DataFrames
# - Identify missing values in a dataframe using built-in methods
# - Evaluate and execute the best strategy for dealing with missing, duplicate, and erroneous values for a given dataset
# - Inspect data for duplicates or extraneous values and remove them
#
#
# ## The dataset
# In this lab, we'll work with the comprehensive [Super Heroes Dataset](https://www.kaggle.com/claudiodavi/superhero-set/data), which can be found on Kaggle!
#
#
# ## Getting Started
#
# In the cell below:
#
# * Import and alias pandas as `pd`
# * Import and alias numpy as `np`
# * Import and alias seaborn as `sns`
# * Import and alias matplotlib.pyplot as `plt`
# * Set matplotlib visualizations to display inline in the notebook

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# For this lab, our dataset is split among two different sources -- `'heroes_information.csv'` and `'super_hero_powers.csv'`.
#
# Use pandas to read in each file and store them in DataFrames in the appropriate variables below. Then, display the `.head()` of each to ensure that everything loaded correctly.

# %%
heroes_df = pd.read_csv('heroes_information.csv')
powers_df = pd.read_csv('super_hero_powers.csv')

heroes_df.head(2)
# Out:
#    Unnamed: 0        name Gender Eye color           Race Hair color  Height  \
# 0           0      A-Bomb   Male    yellow          Human    No Hair   203.0
# 1           1  Abe Sapien   Male      blue  Icthyo Sapien    No Hair   191.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics          -      good   441.0
# 1  Dark Horse Comics       blue      good    65.0

# %%
powers_df.head(2)
# Out:
#   hero_names  Agility  Accelerated Healing  Lantern Power Ring  \
# 0    3-D Man     True                False               False
# 1     A-Bomb    False                 True               False
#
#    Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 0                  False            False       False    False
# 1                  False            False        True    False
#
#    Energy Absorption  Flight  ...  Web Creation  Reality Warping  Odin Force  \
# 0              False   False  ...         False            False       False
# 1              False   False  ...         False            False       False
#
#    Symbiote Costume  Speed Force  Phoenix Force  Molecular Dissipation  \
# 0             False        False          False                  False
# 1             False        False          False                  False
#
#    Vision - Cryo  Omnipresent  Omniscient
# 0          False        False       False
# 1          False        False       False
#
# [2 rows x 168 columns]

# %% [markdown]
# It looks as if the heroes information dataset contained an index column.  We did not specify that this dataset contained an index column, because we hadn't seen it yet. Pandas does not know how to tell apart an index column from any other data, so it stored it with the column name `Unnamed: 0`.
#
# Our DataFrame provided row indices by default, so this column is not needed.  Drop it from the DataFrame in place in the cell below, and then display the head of `heroes_df` to ensure that it worked properly.

# %%
heroes_df.drop('Unnamed: 0', axis=1, inplace=True)
heroes_df.head()
# Out:
#           name Gender Eye color               Race Hair color  Height  \
# 0       A-Bomb   Male    yellow              Human    No Hair   203.0
# 1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair   191.0
# 2     Abin Sur   Male      blue            Ungaran    No Hair   185.0
# 3  Abomination   Male     green  Human / Radiation    No Hair   203.0
# 4      Abraxas   Male      blue      Cosmic Entity      Black   -99.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics          -      good   441.0
# 1  Dark Horse Comics       blue      good    65.0
# 2          DC Comics        red      good    90.0
# 3      Marvel Comics          -       bad   441.0
# 4      Marvel Comics          -       bad   -99.0

# %% [markdown]
# ## Familiarize yourself with the dataset
#
# The first step in our Exploratory Data Analysis will be to get familiar with the data.  This step includes:
#
# * Understanding the dimensionality of your dataset
# * Investigating what type of data it contains, and the data types used to store it
# * Discovering how missing values are encoded, and how many there are
# * Getting a feel for what information it does and doesn't contain
#
# In the cell below, get the descriptive statistics of each DataFrame.

# %%
print(powers_df.columns, "\n\n", heroes_df.columns)
# Out:
# Index(['hero_names', 'Agility', 'Accelerated Healing', 'Lantern Power Ring',
#        'Dimensional Awareness', 'Cold Resistance', 'Durability', 'Stealth',
#        'Energy Absorption', 'Flight',
#        ...
#        'Web Creation', 'Reality Warping', 'Odin Force', 'Symbiote Costume',
#        'Speed Force', 'Phoenix Force', 'Molecular Dissipation',
#        'Vision - Cryo', 'Omnipresent', 'Omniscient'],
#       dtype='object', length=168)
#
#  Index(['name', 'Gender', 'Eye color', 'Race', 'Hair color', 'Height',
#        'Publisher', 'Skin color', 'Alignment', 'Weight'],
#       dtype='object')

# %%
heroes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 734 entries, 0 to 733
# Data columns (total 10 columns):
# name          734 non-null object
# Gender        734 non-null object
# Eye color     734 non-null object
# Race          734 non-null object
# Hair color    734 non-null object
# Height        734 non-null float64
# Publisher     719 non-null object
# Skin color    734 non-null object
# Alignment     734 non-null object
# Weight        732 non-null float64
# dtypes: float64(2), object(8)
# memory usage: 57.5+ KB

# %%
heroes_df.isna().sum()
# Out:
# name           0
# Gender         0
# Eye color      0
# Race           0
# Hair color     0
# Height         0
# Publisher     15
# Skin color     0
# Alignment      0
# Weight         2
# dtype: int64

# %%
powers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Columns: 168 entries, hero_names to Omniscient
# dtypes: bool(167), object(1)
# memory usage: 114.1+ KB

# %%
powers_df.isna().sum()
# Out:
# hero_names               0
# Agility                  0
# Accelerated Healing      0
# Lantern Power Ring       0
# Dimensional Awareness    0
#                         ..
# Phoenix Force            0
# Molecular Dissipation    0
# Vision - Cryo            0
# Omnipresent              0
# Omniscient               0
# Length: 168, dtype: int64

# %%
display(powers_df.describe())
# Out:
#               hero_names Agility Accelerated Healing Lantern Power Ring  \
# count                667     667                 667                667
# unique               667       2                   2                  2
# top     Allan Quatermain   False               False              False
# freq                   1     425                 489                656
#
#        Dimensional Awareness Cold Resistance Durability Stealth  \
# count                    667             667        667     667
# unique                     2               2          2       2
# top                    False           False      False   False
# freq                     642             620        410     541
#
#        Energy Absorption Flight  ... Web Creation Reality Warping Odin Force  \
# count                667    667  ...          667             667        667
# unique                 2      2  ...            2               2          2
# top                False  False  ...        False           False      False
# freq                 590    455  ...          653             651        665
#
#        Symbiote Costume Speed Force Phoenix Force Molecular Dissipation  \
# count               667         667           667                   667
# unique                2           2             2                     2
# top               False       False         False                 False
# freq                658         666           666                   666
#
#        Vision - Cryo Omnipresent Omniscient
# count            667         667        667
# unique             2           2          2
# top            False       False      False
# freq             665         665        665
#
# [4 rows x 168 columns]

# %% [markdown]
# ## Dealing with missing values
#
# Starting in the cell below, detect and deal with any missing values in either DataFrame. Then, explain your methodology for detecting and dealing with outliers in the markdown section below. Be sure to explain your strategy for dealing with missing values in numeric columns, as well as your strategy for dealing with missing values in non-numeric columns.
#
# Note that if you need to add more cells to write code in, you can do this by:
#
# **1.** Highlighting a cell and then pressing `ESC` to enter command mode.
# **2.** Press `A` to add a cell above the highlighted cell, or `B` to add a cell below the highlighted cell.
#
# Describe your strategy below this line:
# ____________________________________________________________________________________________________________________________

# %%
##only missing values are in heros_df in 'Publisher' and 'height' columns.  
#There are 15 values missing in the 'Publisher' and only 2 missing values in 'height'
#There are a total of 667 rows of data, so dropping the column doesn't make any sense. 
#will explore 'Publisher' to see what the values are to determine the best way to fill them in.

# %%
#to fill in the weight, it's pretty easy - calcluate the average weight and use .fillna() populate:
mean_weight = heroes_df['Weight'].mean
heroes_df['Weight'].fillna(mean_weight, inplace=True)
heroes_df.isna().sum()
# Out:
# name           0
# Gender         0
# Eye color      0
# Race           0
# Hair color     0
# Height         0
# Publisher     15
# Skin color     0
# Alignment      0
# Weight         0
# dtype: int64

# %%
heroes_df['Publisher'].unique()
# Out:
# array(['Marvel Comics', 'Dark Horse Comics', 'DC Comics', 'NBC - Heroes',
#        'Wildstorm', 'Image Comics', nan, 'Icon Comics', 'SyFy',
#        'Hanna-Barbera', 'George Lucas', 'Team Epic TV', 'South Park',
#        'HarperCollins', 'ABC Studios', 'Universal Studios', 'Star Trek',
#        'IDW Publishing', 'Shueisha', 'Sony Pictures', 'J. K. Rowling',
#        'Titan Books', 'Rebellion', 'Microsoft', 'J. R. R. Tolkien'],
#       dtype=object)

# %%
##In looking at Heroes, you can see that name might be the same for certain comics... 
## pulling up names
heroes_df.loc[heroes_df["Publisher"].isna()]
# Out:
#                  name  Gender Eye color    Race Hair color  Height Publisher  \
# 46          Astro Boy    Male     brown       -      Black   -99.0       NaN
# 86       Bionic Woman  Female      blue  Cyborg      Black   -99.0       NaN
# 138        Brundlefly    Male         -  Mutant          -   193.0       NaN
# 175      Chuck Norris    Male         -       -          -   178.0       NaN
# 204          Darkside       -         -       -          -   -99.0       NaN
# 244        Ethan Hunt    Male     brown   Human      Brown   168.0       NaN
# 263      Flash Gordon    Male         -       -          -   -99.0       NaN
# 286          Godzilla       -         -   Kaiju          -   108.0       NaN
# 348        Jack Bauer    Male         -       -          -   -99.0       NaN
# 354      Jason Bourne    Male         -   Human          -   -99.0       NaN
# 381  Katniss Everdeen  Female         -   Human          -   -99.0       NaN
# 389         King Kong    Male    yellow  Animal      Black    30.5       NaN
# 393      Kool-Aid Man    Male     black       -    No Hair   -99.0       NaN
# 542             Rambo    Male     brown   Human      Black   178.0       NaN
# 658          The Cape    Male         -       -          -   -99.0       NaN
#
#     Skin color Alignment                                             Weight
# 46           -      good                                                -99
# 86           -      good                                                -99
# 138          -         -                                                -99
# 175          -      good                                                -99
# 204          -       bad                                                -99
# 244          -      good                                                -99
# 263          -      good                                                -99
# 286       grey       bad  <bound method Series.mean of 0      441\n1    ...
# 348          -      good                                                -99
# 354          -      good                                                -99
# 381          -      good                                                -99
# 389          -      good  <bound method Series.mean of 0      441\n1    ...
# 393        red      good                                                -99
# 542          -      good                                                 83
# 658          -      good                                                -99

# %%
##in looking at the data re:publisher is null and looking at the 
##other factors, it's difficult to assign a publisher without consulting an sme

# %%
##heroes_df.pivot((['Publisher'])['Weight'].mean())

# %% [markdown]
# ## Joining, Grouping, and Aggregating
#
# In the cell below, join the two DataFrames.  Think about which sort of join you should use, as well as which columns you should join on.  Rename columns and manipulate as needed.
#
# **_HINT:_** Consider the possibility that the columns you choose to join on contain duplicate entries. If that is the case, devise a strategy to deal with the duplicates.
#
# **_HINT:_** If the join throws an error message, consider setting the column you want to join on as the index for each DataFrame.

# %%
heroes_df.head()
# Out:
#           name Gender Eye color               Race Hair color  Height  \
# 0       A-Bomb   Male    yellow              Human    No Hair   203.0
# 1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair   191.0
# 2     Abin Sur   Male      blue            Ungaran    No Hair   185.0
# 3  Abomination   Male     green  Human / Radiation    No Hair   203.0
# 4      Abraxas   Male      blue      Cosmic Entity      Black   -99.0
#
#            Publisher Skin color Alignment Weight
# 0      Marvel Comics          -      good    441
# 1  Dark Horse Comics       blue      good     65
# 2          DC Comics        red      good     90
# 3      Marvel Comics          -       bad    441
# 4      Marvel Comics          -       bad    -99

# %%
powers_df.head()
# Out:
#     hero_names  Agility  Accelerated Healing  Lantern Power Ring  \
# 0      3-D Man     True                False               False
# 1       A-Bomb    False                 True               False
# 2   Abe Sapien     True                 True               False
# 3     Abin Sur    False                False                True
# 4  Abomination    False                 True               False
#
#    Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 0                  False            False       False    False
# 1                  False            False        True    False
# 2                  False             True        True    False
# 3                  False            False       False    False
# 4                  False            False       False    False
#
#    Energy Absorption  Flight  ...  Web Creation  Reality Warping  Odin Force  \
# 0              False   False  ...         False            False       False
# 1              False   False  ...         False            False       False
# 2              False   False  ...         False            False       False
# 3              False   False  ...         False            False       False
# 4              False   False  ...         False            False       False
#
#    Symbiote Costume  Speed Force  Phoenix Force  Molecular Dissipation  \
# 0             False        False          False                  False
# 1             False        False          False                  False
# 2             False        False          False                  False
# 3             False        False          False                  False
# 4             False        False          False                  False
#
#    Vision - Cryo  Omnipresent  Omniscient
# 0          False        False       False
# 1          False        False       False
# 2          False        False       False
# 3          False        False       False
# 4          False        False       False
#
# [5 rows x 168 columns]

# %%
##Checking for duplicates:
dup_heroes = heroes_df['name'].duplicated()
 
print("Duplicate Rows except first occurrence based on all columns are :")
print(dup_heroes)
# Out:
# Duplicate Rows except first occurrence based on all columns are :
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 729    False
# 730    False
# 731    False
# 732    False
# 733    False
# Name: name, Length: 734, dtype: bool

# %%
##no duplicates based on the fact there are 734 in the lis above 
heroes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 734 entries, 0 to 733
# Data columns (total 10 columns):
# name          734 non-null object
# Gender        734 non-null object
# Eye color     734 non-null object
# Race          734 non-null object
# Hair color    734 non-null object
# Height        734 non-null float64
# Publisher     719 non-null object
# Skin color    734 non-null object
# Alignment     734 non-null object
# Weight        734 non-null object
# dtypes: float64(1), object(9)
# memory usage: 57.5+ KB

# %%
# If I wanted to drop duplicate names:
#heroes_df.drop_duplicates(subset='name', inplace=True)
# Reset index values
#heroes_df.reset_index(drop=True, inplace=True)

# %%
#changing the name of the column so they line up when joining:
powers_df.rename(columns={'hero_names' : 'name'}, inplace=True)

# %%
powers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Columns: 168 entries, name to Omniscient
# dtypes: bool(167), object(1)
# memory usage: 114.1+ KB

# %%
heroes_df.set_index('name', inplace=True)
powers_df.set_index('name', inplace=True)
#can also use # Reset index values
####heroes_df.reset_index(drop=True, inplace=True)

# %%
joined_heroes_df = heroes_df.join(powers_df, how='inner', rsuffix='powers_df')

# %%
joined_heroes_df
# Out:
#                  Gender Eye color               Race        Hair color  \
# name
# A-Bomb             Male    yellow              Human           No Hair
# Abe Sapien         Male      blue      Icthyo Sapien           No Hair
# Abin Sur           Male      blue            Ungaran           No Hair
# Abomination        Male     green  Human / Radiation           No Hair
# Abraxas            Male      blue      Cosmic Entity             Black
# ...                 ...       ...                ...               ...
# Yellowjacket II  Female      blue              Human  Strawberry Blond
# Ymir               Male     white        Frost Giant           No Hair
# Yoda               Male     brown     Yoda's species             White
# Zatanna          Female      blue              Human             Black
# Zoom               Male       red                  -             Brown
#
#                  Height          Publisher Skin color Alignment Weight  \
# name
# A-Bomb            203.0      Marvel Comics          -      good    441
# Abe Sapien        191.0  Dark Horse Comics       blue      good     65
# Abin Sur          185.0          DC Comics        red      good     90
# Abomination       203.0      Marvel Comics          -       bad    441
# Abraxas           -99.0      Marvel Comics          -       bad    -99
# ...                 ...                ...        ...       ...    ...
# Yellowjacket II   165.0      Marvel Comics          -      good     52
# Ymir              304.8      Marvel Comics      white      good    -99
# Yoda               66.0       George Lucas      green      good     17
# Zatanna           170.0          DC Comics          -      good     57
# Zoom              185.0          DC Comics          -       bad     81
#
#                  Agility  ...  Web Creation  Reality Warping  Odin Force  \
# name                      ...
# A-Bomb             False  ...         False            False       False
# Abe Sapien          True  ...         False            False       False
# Abin Sur           False  ...         False            False       False
# Abomination        False  ...         False            False       False
# Abraxas            False  ...         False            False       False
# ...                  ...  ...           ...              ...         ...
# Yellowjacket II    False  ...         False            False       False
# Ymir               False  ...         False            False       False
# Yoda                True  ...         False            False       False
# Zatanna            False  ...         False            False       False
# Zoom               False  ...         False            False       False
#
#                  Symbiote Costume  Speed Force  Phoenix Force  \
# name
# A-Bomb                      False        False          False
# Abe Sapien                  False        False          False
# Abin Sur                    False        False          False
# Abomination                 False        False          False
# Abraxas                     False        False          False
# ...                           ...          ...            ...
# Yellowjacket II             False        False          False
# Ymir                        False        False          False
# Yoda                        False        False          False
# Zatanna                     False        False          False
# Zoom                        False        False          False
#
#                  Molecular Dissipation  Vision - Cryo  Omnipresent  Omniscient
# name
# A-Bomb                           False          False        False       False
# Abe Sapien                       False          False        False       False
# Abin Sur                         False          False        False       False
# Abomination                      False          False        False       False
# Abraxas                          False          False        False       False
# ...                                ...            ...          ...         ...
# Yellowjacket II                  False          False        False       False
# Ymir                             False          False        False       False
# Yoda                             False          False        False       False
# Zatanna                          False          False        False       False
# Zoom                             False          False        False       False
#
# [660 rows x 176 columns]

# %% [markdown]
# In the cell below, subset male and female heroes into different dataframes.  Create a scatterplot of the height and weight of each hero, with weight as the y-axis.  Plot both the male and female heroes subset into each dataframe, and make the color for each point in the scatterplot correspond to the gender of the superhero.

# %%
male_heroes_df = joined_heroes_df[heroes_df['Gender'] == 'Male']
female_heroes_df = joined_heroes_df[heroes_df['Gender'] == 'Female']

ax = male_heroes_df.plot.scatter(x='Height', y='Weight', c='k', label='Male')
female_heroes_df.plot.scatter(x='Height', y='Weight', c='c', label='Female', ax=ax)
# Out:
# C:\Users\aosika\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-f332e9c28676> in <module>
# ----> 1 male_heroes_df = joined_heroes_df[heroes_df['Gender'] == 'Male']
#       2 female_heroes_df = joined_heroes_df[heroes_df['Gender'] == 'Female']
#       3
#       4 ax = male_heroes_df.plot.scatter(x='Height', y='Weight', c='k', label='Male')
#       5 female_heroes_df.plot.scatter(x='Height', y='Weight', c='c', label='Female', ax=ax)
#
# ~\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2969         # Do we have a (boolean) 1d indexer?
#    2970         if com.is_bool_indexer(key):
# -> 2971             return self._getitem_bool_array(key)
#    2972
#    2973         # We are left with two options: a single key, and a collection of keys,
#
# ~\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    3021         # check_bool_indexer will throw exception if Series key cannot
#    3022         # be reindexed to match DataFrame rows
# -> 3023         key = check_bool_indexer(self.index, key)
#    3024         indexer = key.nonzero()[0]
#    3025         return self.take(indexer, axis=0)
#
# ~\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexing.py in check_bool_indexer(index, key)
#    2405     result = key
#    2406     if isinstance(key, ABCSeries) and not key.index.equals(index):
# -> 2407         result = result.reindex(index)
#    2408         mask = isna(result._values)
#    2409         if mask.any():
#
# ~\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\pandas\core\series.py in reindex(self, index, **kwargs)
#    4216     @Appender(generic.NDFrame.reindex.__doc__)
#    4217     def reindex(self, index=None, **kwargs):
# -> 4218         return super().reindex(index=index, **kwargs)
#    4219
#    4220     def drop(
#
# ~\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py in reindex(self, *args, **kwargs)
#    4512         # perform the reindex on the axes
#    4513         return self._reindex_axes(
# -> 4514             axes, level, limit, tolerance, method, fill_value, copy
#    4515         ).__finalize__(self)
#    4516
#
# ~\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4533                 fill_value=fill_value,
#    4534                 copy=copy,
# -> 4535                 allow_dups=False,
#    4536             )
#    4537
#
# ~\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4575                 fill_value=fill_value,
#    4576                 allow_dups=allow_dups,
# -> 4577                 copy=copy,
#    4578             )
#    4579
#
# ~\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\pandas\core\internals\managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1249         # some axes don't allow reindexing with dups
#    1250         if not allow_dups:
# -> 1251             self.axes[axis]._can_reindex(indexer)
#    1252
#    1253         if axis >= self.ndim:
#
# ~\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexes\base.py in _can_reindex(self, indexer)
#    3360         # trying to reindex on an axis with duplicates
#    3361         if not self.is_unique and len(indexer):
# -> 3362             raise ValueError("cannot reindex from a duplicate axis")
#    3363
#    3364     def reindex(self, target, method=None, level=None, limit=None, tolerance=None):
#
# ValueError: cannot reindex from a duplicate axis

# %% [markdown]
# ## Some Initial Investigation
#
# Next, slice the DataFrame as needed and visualize the distribution of heights and weights by gender.  You should have 4 total plots.
#
# In the cell below:
#
# * Slice the DataFrame into separate DataFrames by gender
# * Complete the `show_distplot()` function.  This helper function should take in a DataFrame, a string containing the gender we want to visualize, and the column name we want to visualize by gender. The function should display a distplot visualization from seaborn of the column/gender combination.
#
# Hint: Don't forget to check the [seaborn documentation for distplot](https://seaborn.pydata.org/generated/seaborn.distplot.html) if you have questions about how to use it correctly!

# %%
female_heroes_df = joined_heroes_df[joined_heroes_df['Gender'] == 'Female']
male_heroes_df = joined_heroes_df[joined_heroes_df['Gender'] == 'Male']

# %%
##need to scatter plot

# %%
def show_distplot(dataframe, gender, column_name):
    plt.plot()
    dataframe[column_name].hist()
    plt.title('Distribution of {} for {} heroes'.format(column_name, gender))
    plt.xlabel(column_name)
    plt.ylabel('Probability Density')

# %%
#Male Height
show_distplot(male_heroes_df, 'Male', 'Height')
print('Mean height for male heroes: {}'.format(male_heroes_df.Height.mean()))
print('Median height for male heroes: {}'.format(male_heroes_df.Height.median()))
# Out:
# Mean height for male heroes: 117.08405172413794
# Median height for male heroes: 183.0

# %%
# Male Weight
show_distplot(male_heroes_df, 'Male', 'Weight')
print(f'Mean weight for male heroes: {male_heroes_df.Weight.mean()}')
print(f'Median weight for male heroes: {male_heroes_df.Weight.median()}')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-361b7bb5f02e> in <module>
#       1 # Male Weight
# ----> 2 show_distplot(male_heroes_df, 'Male', 'Weight')
#       3 print(f'Mean weight for male heroes: {male_heroes_df.Weight.mean()}')
#       4 print(f'Median weight for male heroes: {male_heroes_df.Weight.median()}')
#
# <ipython-input-31-45c89e2ebf1d> in show_distplot(dataframe, gender, column_name)
#       1 def show_distplot(dataframe, gender, column_name):
#       2     plt.plot()
# ----> 3     dataframe[column_name].hist()
#       4     plt.title('Distribution of {} for {} heroes'.format(column_name, gender))
#       5     plt.xlabel(column_name)
#
# ~\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\pandas\plotting\_core.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#      83         figsize=figsize,
#      84         bins=bins,
# ---> 85         **kwds
#      86     )
#      87
#
# ~\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\pandas\plotting\_matplotlib\hist.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#     314         values = self.dropna().values
#     315
# --> 316         ax.hist(values, bins=bins, **kwds)
#     317         ax.grid(grid)
#     318         axes = np.array([ax])
#
# ~\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\matplotlib\axes\_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, **kwargs)
#    6733                     # python's min/max ignore nan,
#    6734                     # np.minnan returns nan for all nan input
# -> 6735                     xmin = min(xmin, np.nanmin(xi))
#    6736                     xmax = max(xmax, np.nanmax(xi))
#    6737             # make sure we have seen at least one non-nan and finite
#
# ~\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\numpy\lib\nanfunctions.py in nanmin(a, axis, out, keepdims)
#     296         # Slow, but safe for subclasses of ndarray
#     297         a, mask = _replace_nan(a, +np.inf)
# --> 298         res = np.amin(a, axis=axis, out=out, **kwargs)
#     299         if mask is None:
#     300             return res
#
# ~\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\numpy\core\fromnumeric.py in amin(a, axis, out, keepdims, initial)
#    2616     """
#    2617     return _wrapreduction(a, np.minimum, 'min', axis, None, out, keepdims=keepdims,
# -> 2618                           initial=initial)
#    2619
#    2620
#
# ~\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\numpy\core\fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84                 return reduction(axis=axis, out=out, **passkwargs)
#      85
# ---> 86     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      87
#      88
#
# TypeError: '<=' not supported between instances of 'float' and 'method'

# %%
# Female Height
show_distplot(female_heroes_df, 'Female', 'Height')
print(f'Mean height for female heroes: {female_heroes_df.Height.mean()}')
print(f'Median height for female heroes: {female_heroes_df.Height.median()}')
# Out:
# Mean height for female heroes: 98.0525
# Median height for female heroes: 168.0

# %%
# Female Weight

show_distplot(female_heroes_df, 'Female', 'Weight')
print(f'Mean weight for female heroes: {female_heroes_df.Weight.mean()}')
print(f'Median weight for female heroes: {female_heroes_df.Weight.median()}')
# Out:
# Mean weight for female heroes: 27.265
# Median weight for female heroes: 54.0

# %% [markdown]
# Discuss your findings from the plots above, with respect to the distribution of height and weight by gender.  Your explanation should include a discussion of any relevant summary statistics, including mean, median, mode, and the overall shape of each distribution.
#
# Write your answer below this line:
# ____________________________________________________________________________________________________________________________

# %% [markdown]
# ### Sample Question: Most Common Powers
#
# The rest of this notebook will be left to you to investigate the dataset by formulating your own questions, and then seeking answers using pandas and numpy.  Every answer should include some sort of visualization, when appropriate. Before moving on to formulating your own questions, use the dataset to answer the following questions about superhero powers:
#
# * What are the 5 most common powers overall?
# * What are the 5 most common powers in the Marvel Universe?
# * What are the 5 most common powers in the DC Universe?

# %%
powers_df.columns
# Out:
# Index(['Agility', 'Accelerated Healing', 'Lantern Power Ring',
#        'Dimensional Awareness', 'Cold Resistance', 'Durability', 'Stealth',
#        'Energy Absorption', 'Flight', 'Danger Sense',
#        ...
#        'Web Creation', 'Reality Warping', 'Odin Force', 'Symbiote Costume',
#        'Speed Force', 'Phoenix Force', 'Molecular Dissipation',
#        'Vision - Cryo', 'Omnipresent', 'Omniscient'],
#       dtype='object', length=167)

# %%
powers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 667 entries, 3-D Man to Zoom
# Columns: 167 entries, Agility to Omniscient
# dtypes: bool(167)
# memory usage: 134.0+ KB

# %%
#bool_dict = {'True' : True , 'False' : False}

# %%
### code to map the dictionary to the variable:
#powers_df['Agility'].map(bool_dict).sum()

# %%
#superpower_dict = {}
#for power in powers_df.columns[1:]:
    ###dropping in the .map(bool_dict).sum() to the power variable
    ##my_col = powers_df[power].map(bool_dict).sum()
    ##superpower_dict[power] = my_col

# %%
powers_df[1:].sum().sort_values(ascending=False)
# Out:
# Super Strength          359
# Stamina                 288
# Durability              257
# Super Speed             248
# Agility                 241
#                        ...
# Electrical Transport      1
# Hair Manipulation         1
# Hyperkinesis              1
# Intuitive aptitude        1
# Thirstokinesis            1
# Length: 167, dtype: int64

# %%
to_sort = powers_df[1:].sum().sort_values(ascending=False)
to_sort.iloc[:5].plot(kind='barh')

# %%
def sorted_powers(dataframe):
    for power in joined
    powers_df[1:].sum().sort_values(ascending=False)
# Out:
#   File "<ipython-input-160-e5ab18ebac9b>", line 1
#     def sorted_powers(dataframe)
#                                 ^
# SyntaxError: invalid syntax

# %%
Publisher_df = joined_heroes_df.groupby('Publisher')
Publisher_df.head()
# Out:
#                   Gender Eye color               Race Hair color  Height  \
# name
# A-Bomb              Male    yellow              Human    No Hair   203.0
# Abe Sapien          Male      blue      Icthyo Sapien    No Hair   191.0
# Abin Sur            Male      blue            Ungaran    No Hair   185.0
# Abomination         Male     green  Human / Radiation    No Hair   203.0
# Abraxas             Male      blue      Cosmic Entity      Black   -99.0
# ...                  ...       ...                ...        ...     ...
# Sauron              Male         -              Maiar          -   279.0
# Stephanie Powell  Female         -                  -      Blond   -99.0
# Titan               Male         -                  -          -   -99.0
# Valerie Hart      Female     hazel                  -      Black   175.0
# Vegeta              Male         -             Saiyan      Black   168.0
#
#                           Publisher Skin color Alignment Weight  Agility  ...  \
# name                                                                      ...
# A-Bomb                Marvel Comics          -      good    441    False  ...
# Abe Sapien        Dark Horse Comics       blue      good     65     True  ...
# Abin Sur                  DC Comics        red      good     90    False  ...
# Abomination           Marvel Comics          -       bad    441    False  ...
# Abraxas               Marvel Comics          -       bad    -99    False  ...
# ...                             ...        ...       ...    ...      ...  ...
# Sauron             J. R. R. Tolkien          -       bad    -99    False  ...
# Stephanie Powell        ABC Studios          -      good    -99    False  ...
# Titan                 HarperCollins          -      good    -99    False  ...
# Valerie Hart           Team Epic TV          -      good     56     True  ...
# Vegeta                     Shueisha          -       bad     73     True  ...
#
#                   Web Creation  Reality Warping  Odin Force  Symbiote Costume  \
# name
# A-Bomb                   False            False       False             False
# Abe Sapien               False            False       False             False
# Abin Sur                 False            False       False             False
# Abomination              False            False       False             False
# Abraxas                  False            False       False             False
# ...                        ...              ...         ...               ...
# Sauron                   False            False       False             False
# Stephanie Powell         False            False       False             False
# Titan                    False            False       False             False
# Valerie Hart             False            False       False             False
# Vegeta                   False            False       False             False
#
#                   Speed Force  Phoenix Force  Molecular Dissipation  \
# name
# A-Bomb                  False          False                  False
# Abe Sapien              False          False                  False
# Abin Sur                False          False                  False
# Abomination             False          False                  False
# Abraxas                 False          False                  False
# ...                       ...            ...                    ...
# Sauron                  False          False                  False
# Stephanie Powell        False          False                  False
# Titan                   False          False                  False
# Valerie Hart            False          False                  False
# Vegeta                  False          False                  False
#
#                   Vision - Cryo  Omnipresent  Omniscient
# name
# A-Bomb                    False        False       False
# Abe Sapien                False        False       False
# Abin Sur                  False        False       False
# Abomination               False        False       False
# Abraxas                   False        False       False
# ...                         ...          ...         ...
# Sauron                    False        False       False
# Stephanie Powell          False        False       False
# Titan                     False        False       False
# Valerie Hart              False        False       False
# Vegeta                    False        False       False
#
# [81 rows x 176 columns]

# %%
top_5 = to_sort[0:5]
top_5
# Out:
# Super Strength    359
# Stamina           288
# Durability        257
# Super Speed       248
# Agility           241
# dtype: int64

# %%
type(top_5)
# Out:
# pandas.core.series.Series

# %%
 #joined_heroes_df[1:]('Publisher' == "Marvel").sum().sort_values(ascending=False)

# %%
def top_5_powers(dataframe):
    df = dataframe.drop(heroes_df.columns.values[1:], axis=1)
    columns = df.columns.values
    for col in columns:
        df[col] = df[col].map({'True': 1, 'False': 0})
        
    power_counts_dict = dict(df.sum())
    
    return sorted(power_counts_dict.items(), key=lambda x: x[1], reverse=True)[:5] 
    
overall_top_5 = top_5_powers(joined_heroes_df)
marvel_df = joined_heroes_df[joined_heroes_df['Publisher'] == 'Marvel Comics']
dc_df = joined_heroes_df[joined_heroes_df['Publisher'] == 'DC Comics']
print(overall_top_5)
# Out:
# [('Gender', 0.0), ('Agility', 0.0), ('Accelerated Healing', 0.0), ('Lantern Power Ring', 0.0), ('Dimensional Awareness', 0.0)]

# %%
marvel_df = joined_heroes_df[joined_heroes_df['Publisher'] == 'Marvel Comics']
marvel_df.map(top_5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-148-77a04df3f272> in <module>
#       1 marvel_df = joined_heroes_df[joined_heroes_df['Publisher'] == 'Marvel Comics']
# ----> 2 marvel_df.map(top_5)
#
# ~\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'map'

# %% [markdown]
# Analyze the results you found above to answer the following question:
#
# How do the top 5 powers in the Marvel and DC universes compare?  Are they similar, or are there significant differences? How do they compare to the overall trends in the entire Superheroes dataset?
#
# Write your answer below this line:
# ____________________________________________________________________________________________________________________________
#
#
# ### Your Own Investigation
#
# For the remainder of this lab, you'll be focusing on coming up with and answering your own question, just like we did above.  Your question should not be overly simple, and should require both descriptive statistics and data visualization to answer.  In case you're unsure of what questions to ask, some sample questions have been provided below.
#
# Pick one of the following questions to investigate and answer, or come up with one of your own!
#
# * Which powers have the highest chance of co-occurring in a hero (e.g. super strength and flight), and does this differ by gender?
# * Is there a relationship between a hero's height and weight and their powerset?
# * What is the distribution of skin colors amongst alien heroes?
#
# Explain your question below this line:
# ____________________________________________________________________________________________________________________________
#
#
#
# Some sample cells have been provided to give you room to work. If you need to create more cells, you can do this easily by:
#
# 1. Highlighting a cell and then pressing `esc` to enter command mode.
# 1. Pressing `b` to add a cell below the currently highlighted cell, or `a` to add one above it.
#
# Be sure to include thoughtful, well-labeled visualizations to back up your analysis!

# %%
plt.hist(joined_heroes_df['Skin color'],bins=(30))
# Out:
# (array([588.,   9.,   0.,   9.,   0.,   1.,   0.,   5.,   0.,   3.,   0.,
#          21.,   0.,   7.,   0.,   2.,   5.,   0.,   1.,   0.,   2.,   0.,
#           3.,   0.,   1.,   0.,   1.,   0.,   1.,   1.]),
#  array([ 0.        ,  0.53333333,  1.06666667,  1.6       ,  2.13333333,
#          2.66666667,  3.2       ,  3.73333333,  4.26666667,  4.8       ,
#          5.33333333,  5.86666667,  6.4       ,  6.93333333,  7.46666667,
#          8.        ,  8.53333333,  9.06666667,  9.6       , 10.13333333,
#         10.66666667, 11.2       , 11.73333333, 12.26666667, 12.8       ,
#         13.33333333, 13.86666667, 14.4       , 14.93333333, 15.46666667,
#         16.        ]),
#  <a list of 30 Patch objects>)

# %%
joined_heroes_df.head()
# Out:
#             Gender Eye color               Race Hair color  Height  \
# name
# A-Bomb        Male    yellow              Human    No Hair   203.0
# Abe Sapien    Male      blue      Icthyo Sapien    No Hair   191.0
# Abin Sur      Male      blue            Ungaran    No Hair   185.0
# Abomination   Male     green  Human / Radiation    No Hair   203.0
# Abraxas       Male      blue      Cosmic Entity      Black   -99.0
#
#                      Publisher Skin color Alignment Weight  Agility  ...  \
# name                                                                 ...
# A-Bomb           Marvel Comics          -      good    441    False  ...
# Abe Sapien   Dark Horse Comics       blue      good     65     True  ...
# Abin Sur             DC Comics        red      good     90    False  ...
# Abomination      Marvel Comics          -       bad    441    False  ...
# Abraxas          Marvel Comics          -       bad    -99    False  ...
#
#              Web Creation  Reality Warping  Odin Force  Symbiote Costume  \
# name
# A-Bomb              False            False       False             False
# Abe Sapien          False            False       False             False
# Abin Sur            False            False       False             False
# Abomination         False            False       False             False
# Abraxas             False            False       False             False
#
#              Speed Force  Phoenix Force  Molecular Dissipation  Vision - Cryo  \
# name
# A-Bomb             False          False                  False          False
# Abe Sapien         False          False                  False          False
# Abin Sur           False          False                  False          False
# Abomination        False          False                  False          False
# Abraxas            False          False                  False          False
#
#              Omnipresent  Omniscient
# name
# A-Bomb             False       False
# Abe Sapien         False       False
# Abin Sur           False       False
# Abomination        False       False
# Abraxas            False       False
#
# [5 rows x 176 columns]

# %%
import pandas as pd

# %%
cor_powers={}

for power in joined_heroes_df:
    if power == True:
        count = powers_df[1:].sum()
        cor_powers[power]= count

# %%
Super Strength    359
Stamina           288
Durability        257
Super Speed       248
Agility           241

# %%
show_distplot(joined_heroes_df, 'Super_Strength', 'Weight')
print(f'Mean weight for heroes: {joined_heroes_df.Weight.mean()}')
print(f'Median weight for heroes: {joined_heroes_df.Weight.median()}')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-150-778af683fa0b> in <module>
# ----> 1 show_distplot(joined_heroes_df, 'Super_Strength', 'Weight')
#       2 print(f'Mean weight for heroes: {joined_heroes_df.Weight.mean()}')
#       3 print(f'Median weight for heroes: {joined_heroes_df.Weight.median()}')
#
# <ipython-input-142-45c89e2ebf1d> in show_distplot(dataframe, gender, column_name)
#       1 def show_distplot(dataframe, gender, column_name):
#       2     plt.plot()
# ----> 3     dataframe[column_name].hist()
#       4     plt.title('Distribution of {} for {} heroes'.format(column_name, gender))
#       5     plt.xlabel(column_name)
#
# ~\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\pandas\plotting\_core.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#      83         figsize=figsize,
#      84         bins=bins,
# ---> 85         **kwds
#      86     )
#      87
#
# ~\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\pandas\plotting\_matplotlib\hist.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#     314         values = self.dropna().values
#     315
# --> 316         ax.hist(values, bins=bins, **kwds)
#     317         ax.grid(grid)
#     318         axes = np.array([ax])
#
# ~\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\matplotlib\axes\_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, **kwargs)
#    6733                     # python's min/max ignore nan,
#    6734                     # np.minnan returns nan for all nan input
# -> 6735                     xmin = min(xmin, np.nanmin(xi))
#    6736                     xmax = max(xmax, np.nanmax(xi))
#    6737             # make sure we have seen at least one non-nan and finite
#
# ~\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\numpy\lib\nanfunctions.py in nanmin(a, axis, out, keepdims)
#     296         # Slow, but safe for subclasses of ndarray
#     297         a, mask = _replace_nan(a, +np.inf)
# --> 298         res = np.amin(a, axis=axis, out=out, **kwargs)
#     299         if mask is None:
#     300             return res
#
# ~\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\numpy\core\fromnumeric.py in amin(a, axis, out, keepdims, initial)
#    2616     """
#    2617     return _wrapreduction(a, np.minimum, 'min', axis, None, out, keepdims=keepdims,
# -> 2618                           initial=initial)
#    2619
#    2620
#
# ~\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\numpy\core\fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84                 return reduction(axis=axis, out=out, **passkwargs)
#      85
# ---> 86     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      87
#      88
#
# TypeError: '<=' not supported between instances of 'float' and 'method'

# %% [markdown]
# ## Summary
#
# In this lab, we demonstrated our mastery of:
# * Using all of our Pandas knowledge to date to clean the dataset and deal with null values
# * Using Queries and aggregations to group the data into interesting subsets as needed
# * Using descriptive statistics and data visualization to find answers to questions we may have about the data
